# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        print("OK")
        print(city.title())
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        #print(city_lat)
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # cw = city_weather["weather"]
        # dc = cw[0]
        city_weather_description = city_weather["weather"][0]["description"]
        # print(city_weather_description)
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bagdarin
# OK
# Bagdarin
# Processing Record 2 of Set 1 | ushuaia
# OK
# Ushuaia
# Processing Record 3 of Set 1 | airai
# OK
# Airai
# Processing Record 4 of Set 1 | barentsburg
# OK
# Barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | sibolga
# OK
# Sibolga
# Processing Record 6 of Set 1 | hovd
# OK
# Hovd
# Processing Record 7 of Set 1 | jonesboro
# OK
# Jonesboro
# Processing Record 8 of Set 1 | castro
# OK
# Castro
# Processing Record 9 of Set 1 | norman wells
# OK
# Norman Wells
# Processing Record 10 of Set 1 | asau
# OK
# Asau
# Processing Record 11 of Set 1 | new norfolk
# OK
# New Norfolk
# Processing Record 12 of Set 1 | kapaa
# OK
# Kapaa
# Processing Record 13 of Set 1 | chuy
# OK
# Chuy
# Processing Record 14 of Set 1 | avarua
# OK
# Avarua
# Processing Record 15 of Set 1 | vaini
# OK
# Vaini
# Processing Record 16 of Set 1 | chokurdakh
# OK
# Chokurdakh
# Processing Record 17 of Set 1 | charters towers
# OK
# Charters Towers
# Processing Record 18 of Set 1 | jacareacanga
# OK
# Jacareacanga
# Processing Record 19 of Set 1 | ust-omchug
# OK
# Ust-Omchug
# Processing Record 20 of Set 1 | clyde river
# OK
# Clyde River
# Processing Record 21 of Set 1 | lubeck
# OK
# Lubeck
# Processing Record 22 of Set 1 | hermanus
# OK
# Hermanus
# Processing Record 23 of Set 1 | general roca
# OK
# General Roca
# Processing Record 24 of Set 1 | khatanga
# OK
# Khatanga
# Processing Record 25 of Set 1 | tucuman
# OK
# Tucuman
# Processing Record 26 of Set 1 | luanda
# OK
# Luanda
# Processing Record 27 of Set 1 | necochea
# OK
# Necochea
# Processing Record 28 of Set 1 | rawson
# OK
# Rawson
# Processing Record 29 of Set 1 | roma
# OK
# Roma
# Processing Record 30 of Set 1 | busselton
# OK
# Busselton
# Processing Record 31 of Set 1 | barrow
# OK
# Barrow
# Processing Record 32 of Set 1 | changli
# OK
# Changli
# Processing Record 33 of Set 1 | riyadh
# OK
# Riyadh
# Processing Record 34 of Set 1 | milkovo
# OK
# Milkovo
# Processing Record 35 of Set 1 | santa maria
# OK
# Santa Maria
# Processing Record 36 of Set 1 | bathsheba
# OK
# Bathsheba
# Processing Record 37 of Set 1 | taolanaro
# OK
# Taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | bonfim
# OK
# Bonfim
# Processing Record 39 of Set 1 | fraga
# OK
# Fraga
# Processing Record 40 of Set 1 | gawler
# OK
# Gawler
# Processing Record 41 of Set 1 | padang
# OK
# Padang
# Processing Record 42 of Set 1 | zenzeli
# OK
# Zenzeli
# Processing Record 43 of Set 1 | lebu
# OK
# Lebu
# Processing Record 44 of Set 1 | hithadhoo
# OK
# Hithadhoo
# Processing Record 45 of Set 1 | orlik
# OK
# Orlik
# Processing Record 46 of Set 1 | san francisco
# OK
# San Francisco
# Processing Record 47 of Set 1 | cape town
# OK
# Cape Town
# Processing Record 48 of Set 1 | yellowknife
# OK
# Yellowknife
# Processing Record 49 of Set 1 | lixourion
# OK
# Lixourion
# Processing Record 50 of Set 1 | pitimbu
# OK
# Pitimbu
# Processing Record 1 of Set 2 | butaritari
# OK
# Butaritari
# Processing Record 2 of Set 2 | katsuura
# OK
# Katsuura
# Processing Record 3 of Set 2 | rikitea
# OK
# Rikitea
# Processing Record 4 of Set 2 | shishou
# OK
# Shishou
# Processing Record 5 of Set 2 | tuktoyaktuk
# OK
# Tuktoyaktuk
# Processing Record 6 of Set 2 | laguna
# OK
# Laguna
# Processing Record 7 of Set 2 | kahului
# OK
# Kahului
# Processing Record 8 of Set 2 | sentyabrskiy
# OK
# Sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | klyuchi
# OK
# Klyuchi
# Processing Record 10 of Set 2 | nikolskoye
# OK
# Nikolskoye
# Processing Record 11 of Set 2 | jamestown
# OK
# Jamestown
# Processing Record 12 of Set 2 | ancud
# OK
# Ancud
# Processing Record 13 of Set 2 | kudahuvadhoo
# OK
# Kudahuvadhoo
# Processing Record 14 of Set 2 | cabo san lucas
# OK
# Cabo San Lucas
# Processing Record 15 of Set 2 | svetlaya
# OK
# Svetlaya
# Processing Record 16 of Set 2 | aykhal
# OK
# Aykhal
# Processing Record 17 of Set 2 | podor
# OK
# Podor
# Processing Record 18 of Set 2 | dikson
# OK
# Dikson
# Processing Record 19 of Set 2 | kruisfontein
# OK
# Kruisfontein
# Processing Record 20 of Set 2 | taoudenni
# OK
# Taoudenni
# Processing Record 21 of Set 2 | turukhansk
# OK
# Turukhansk
# Processing Record 22 of Set 2 | victoria
# OK
# Victoria
# Processing Record 23 of Set 2 | albany
# OK
# Albany
# Processing Record 24 of Set 2 | praia da vitoria
# OK
# Praia Da Vitoria
# Processing Record 25 of Set 2 | rocha
# OK
# Rocha
# Processing Record 26 of Set 2 | bluff
# OK
# Bluff
# Processing Record 27 of Set 2 | sobolevo
# OK
# Sobolevo
# Processing Record 28 of Set 2 | waddan
# OK
# Waddan
# Processing Record 29 of Set 2 | vestmannaeyjar
# OK
# Vestmannaeyjar
# Processing Record 30 of Set 2 | tasiilaq
# OK
# Tasiilaq
# Processing Record 31 of Set 2 | namibe
# OK
# Namibe
# Processing Record 32 of Set 2 | torrevieja
# OK
# Torrevieja
# Processing Record 33 of Set 2 | mataura
# OK
# Mataura
# Processing Record 34 of Set 2 | hobart
# OK
# Hobart
# Processing Record 35 of Set 2 | honiara
# OK
# Honiara
# Processing Record 36 of Set 2 | punta arenas
# OK
# Punta Arenas
# Processing Record 37 of Set 2 | rio grande
# OK
# Rio Grande
# Processing Record 38 of Set 2 | ingham
# OK
# Ingham
# Processing Record 39 of Set 2 | mar del plata
# OK
# Mar Del Plata
# Processing Record 40 of Set 2 | banjar
# OK
# Banjar
# Processing Record 41 of Set 2 | hambantota
# OK
# Hambantota
# Processing Record 42 of Set 2 | altos
# OK
# Altos
# Processing Record 43 of Set 2 | praya
# OK
# Praya
# Processing Record 44 of Set 2 | mitchell
# OK
# Mitchell
# Processing Record 45 of Set 2 | cochrane
# OK
# Cochrane
# Processing Record 46 of Set 2 | el cope
# OK
# El Cope
# Processing Record 47 of Set 2 | port elizabeth
# OK
# Port Elizabeth
# Processing Record 48 of Set 2 | zhangye
# OK
# Zhangye
# Processing Record 49 of Set 2 | puerto ayora
# OK
# Puerto Ayora
# Processing Record 50 of Set 2 | mahebourg
# OK
# Mahebourg
# Processing Record 1 of Set 3 | los llanos de aridane
# OK
# Los Llanos De Aridane
# Processing Record 2 of Set 3 | rio novo do sul
# OK
# Rio Novo Do Sul
# Processing Record 3 of Set 3 | the valley
# OK
# The Valley
# Processing Record 4 of Set 3 | aswan
# OK
# Aswan
# Processing Record 5 of Set 3 | kutum
# OK
# Kutum
# Processing Record 6 of Set 3 | leh
# OK
# Leh
# Processing Record 7 of Set 3 | byron bay
# OK
# Byron Bay
# Processing Record 8 of Set 3 | brigantine
# OK
# Brigantine
# Processing Record 9 of Set 3 | ardistan
# OK
# Ardistan
# City not found. Skipping...
# Processing Record 10 of Set 3 | kieta
# OK
# Kieta
# Processing Record 11 of Set 3 | tapaua
# OK
# Tapaua
# City not found. Skipping...
# Processing Record 12 of Set 3 | gerash
# OK
# Gerash
# Processing Record 13 of Set 3 | westport
# OK
# Westport
# Processing Record 14 of Set 3 | itoman
# OK
# Itoman
# Processing Record 15 of Set 3 | adrar
# OK
# Adrar
# Processing Record 16 of Set 3 | vilyuysk
# OK
# Vilyuysk
# Processing Record 17 of Set 3 | mount gambier
# OK
# Mount Gambier
# Processing Record 18 of Set 3 | antofagasta
# OK
# Antofagasta
# Processing Record 19 of Set 3 | dukat
# OK
# Dukat
# Processing Record 20 of Set 3 | orange cove
# OK
# Orange Cove
# Processing Record 21 of Set 3 | evenskjaer
# OK
# Evenskjaer
# City not found. Skipping...
# Processing Record 22 of Set 3 | fortuna
# OK
# Fortuna
# Processing Record 23 of Set 3 | muisne
# OK
# Muisne
# Processing Record 24 of Set 3 | port alfred
# OK
# Port Alfred
# Processing Record 25 of Set 3 | garden city
# OK
# Garden City
# Processing Record 26 of Set 3 | thompson
# OK
# Thompson
# Processing Record 27 of Set 3 | atuona
# OK
# Atuona
# Processing Record 28 of Set 3 | talara
# OK
# Talara
# Processing Record 29 of Set 3 | saint-joseph
# OK
# Saint-Joseph
# Processing Record 30 of Set 3 | saint-philippe
# OK
# Saint-Philippe
# Processing Record 31 of Set 3 | babanusah
# OK
# Babanusah
# City not found. Skipping...
# Processing Record 32 of Set 3 | aguas formosas
# OK
# Aguas Formosas
# Processing Record 33 of Set 3 | attawapiskat
# OK
# Attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 3 | hilo
# OK
# Hilo
# Processing Record 35 of Set 3 | vaitupu
# OK
# Vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 3 | tatui
# OK
# Tatui
# Processing Record 37 of Set 3 | louisbourg
# OK
# Louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 3 | meulaboh
# OK
# Meulaboh
# Processing Record 39 of Set 3 | nizhneyansk
# OK
# Nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 3 | kavieng
# OK
# Kavieng
# Processing Record 41 of Set 3 | lamidan
# OK
# Lamidan
# City not found. Skipping...
# Processing Record 42 of Set 3 | aklavik
# OK
# Aklavik
# Processing Record 43 of Set 3 | ponta do sol
# OK
# Ponta Do Sol
# Processing Record 44 of Set 3 | sukumo
# OK
# Sukumo
# Processing Record 45 of Set 3 | nagahama
# OK
# Nagahama
# Processing Record 46 of Set 3 | jalna
# OK
# Jalna
# Processing Record 47 of Set 3 | vao
# OK
# Vao
# Processing Record 48 of Set 3 | comodoro rivadavia
# OK
# Comodoro Rivadavia
# Processing Record 49 of Set 3 | santa fe do sul
# OK
# Santa Fe Do Sul
# Processing Record 50 of Set 3 | namatanai
# OK
# Namatanai
# Processing Record 1 of Set 4 | parrita
# OK
# Parrita
# Processing Record 2 of Set 4 | bambanglipuro
# OK
# Bambanglipuro
# Processing Record 3 of Set 4 | half moon bay
# OK
# Half Moon Bay
# Processing Record 4 of Set 4 | arraial do cabo
# OK
# Arraial Do Cabo
# Processing Record 5 of Set 4 | puerto escondido
# OK
# Puerto Escondido
# Processing Record 6 of Set 4 | provideniya
# OK
# Provideniya
# Processing Record 7 of Set 4 | portage
# OK
# Portage
# Processing Record 8 of Set 4 | olafsvik
# OK
# Olafsvik
# Processing Record 9 of Set 4 | huarmey
# OK
# Huarmey
# Processing Record 10 of Set 4 | quelimane
# OK
# Quelimane
# Processing Record 11 of Set 4 | maniitsoq
# OK
# Maniitsoq
# Processing Record 12 of Set 4 | amderma
# OK
# Amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | nanortalik
# OK
# Nanortalik
# Processing Record 14 of Set 4 | dingle
# OK
# Dingle
# Processing Record 15 of Set 4 | aravissos
# OK
# Aravissos
# Processing Record 16 of Set 4 | delano
# OK
# Delano
# Processing Record 17 of Set 4 | cartagena
# OK
# Cartagena
# Processing Record 18 of Set 4 | narsaq
# OK
# Narsaq
# Processing Record 19 of Set 4 | malm
# OK
# Malm
# Processing Record 20 of Set 4 | le mans
# OK
# Le Mans
# Processing Record 21 of Set 4 | salalah
# OK
# Salalah
# Processing Record 22 of Set 4 | lincoln
# OK
# Lincoln
# Processing Record 23 of Set 4 | sao joao da barra
# OK
# Sao Joao Da Barra
# Processing Record 24 of Set 4 | balkanabat
# OK
# Balkanabat
# Processing Record 25 of Set 4 | mata
# OK
# Mata
# Processing Record 26 of Set 4 | longyearbyen
# OK
# Longyearbyen
# Processing Record 27 of Set 4 | panama city
# OK
# Panama City
# Processing Record 28 of Set 4 | lorengau
# OK
# Lorengau
# Processing Record 29 of Set 4 | ibra
# OK
# Ibra
# Processing Record 30 of Set 4 | carney
# OK
# Carney
# Processing Record 31 of Set 4 | zhigansk
# OK
# Zhigansk
# Processing Record 32 of Set 4 | glubokoe
# OK
# Glubokoe
# City not found. Skipping...
# Processing Record 33 of Set 4 | sisimiut
# OK
# Sisimiut
# Processing Record 34 of Set 4 | hvide sande
# OK
# Hvide Sande
# Processing Record 35 of Set 4 | mildura
# OK
# Mildura
# Processing Record 36 of Set 4 | anadyr
# OK
# Anadyr
# Processing Record 37 of Set 4 | ondangwa
# OK
# Ondangwa
# Processing Record 38 of Set 4 | east london
# OK
# East London
# Processing Record 39 of Set 4 | dagda
# OK
# Dagda
# Processing Record 40 of Set 4 | kayerkan
# OK
# Kayerkan
# Processing Record 41 of Set 4 | asyut
# OK
# Asyut
# Processing Record 42 of Set 4 | bari
# OK
# Bari
# Processing Record 43 of Set 4 | mhlume
# OK
# Mhlume
# Processing Record 44 of Set 4 | kuito
# OK
# Kuito
# Processing Record 45 of Set 4 | champerico
# OK
# Champerico
# Processing Record 46 of Set 4 | avera
# OK
# Avera
# Processing Record 47 of Set 4 | belushya guba
# OK
# Belushya Guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | basoko
# OK
# Basoko
# Processing Record 49 of Set 4 | tazovskiy
# OK
# Tazovskiy
# Processing Record 50 of Set 4 | kirkenes
# OK
# Kirkenes
# Processing Record 1 of Set 5 | geraldton
# OK
# Geraldton
# Processing Record 2 of Set 5 | esperance
# OK
# Esperance
# Processing Record 3 of Set 5 | palabuhanratu
# OK
# Palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | umm lajj
# OK
# Umm Lajj
# Processing Record 5 of Set 5 | torit
# OK
# Torit
# Processing Record 6 of Set 5 | shkotovo-26
# OK
# Shkotovo-26
# City not found. Skipping...
# Processing Record 7 of Set 5 | mys shmidta
# OK
# Mys Shmidta
# City not found. Skipping...
# Processing Record 8 of Set 5 | pittsburg
# OK
# Pittsburg
# Processing Record 9 of Set 5 | qaqortoq
# OK
# Qaqortoq
# Processing Record 10 of Set 5 | olney
# OK
# Olney
# Processing Record 11 of Set 5 | severo-yeniseyskiy
# OK
# Severo-Yeniseyskiy
# Processing Record 12 of Set 5 | bethel
# OK
# Bethel
# Processing Record 13 of Set 5 | banda aceh
# OK
# Banda Aceh
# Processing Record 14 of Set 5 | gigmoto
# OK
# Gigmoto
# Processing Record 15 of Set 5 | iqaluit
# OK
# Iqaluit
# Processing Record 16 of Set 5 | bredasdorp
# OK
# Bredasdorp
# Processing Record 17 of Set 5 | paamiut
# OK
# Paamiut
# Processing Record 18 of Set 5 | kwinana
# OK
# Kwinana
# Processing Record 19 of Set 5 | ilulissat
# OK
# Ilulissat
# Processing Record 20 of Set 5 | port lincoln
# OK
# Port Lincoln
# Processing Record 21 of Set 5 | kaitangata
# OK
# Kaitangata
# Processing Record 22 of Set 5 | mangrol
# OK
# Mangrol
# Processing Record 23 of Set 5 | kudat
# OK
# Kudat
# Processing Record 24 of Set 5 | aripuana
# OK
# Aripuana
# Processing Record 25 of Set 5 | port-cartier
# OK
# Port-Cartier
# Processing Record 26 of Set 5 | beyneu
# OK
# Beyneu
# Processing Record 27 of Set 5 | bud
# OK
# Bud
# Processing Record 28 of Set 5 | corralillo
# OK
# Corralillo
# Processing Record 29 of Set 5 | butte
# OK
# Butte
# Processing Record 30 of Set 5 | virden
# OK
# Virden
# Processing Record 31 of Set 5 | fria
# OK
# Fria
# Processing Record 32 of Set 5 | salina
# OK
# Salina
# Processing Record 33 of Set 5 | manzhouli
# OK
# Manzhouli
# Processing Record 34 of Set 5 | husavik
# OK
# Husavik
# Processing Record 35 of Set 5 | carnarvon
# OK
# Carnarvon
# Processing Record 36 of Set 5 | warqla
# OK
# Warqla
# City not found. Skipping...
# Processing Record 37 of Set 5 | copiapo
# OK
# Copiapo
# Processing Record 38 of Set 5 | egvekinot
# OK
# Egvekinot
# Processing Record 39 of Set 5 | umzimvubu
# OK
# Umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 5 | vardo
# OK
# Vardo
# Processing Record 41 of Set 5 | eganville
# OK
# Eganville
# Processing Record 42 of Set 5 | ganzhou
# OK
# Ganzhou
# Processing Record 43 of Set 5 | gainesville
# OK
# Gainesville
# Processing Record 44 of Set 5 | grand gaube
# OK
# Grand Gaube
# Processing Record 45 of Set 5 | mudyuga
# OK
# Mudyuga
# City not found. Skipping...
# Processing Record 46 of Set 5 | auki
# OK
# Auki
# Processing Record 47 of Set 5 | georgetown
# OK
# Georgetown
# Processing Record 48 of Set 5 | inderborskiy
# OK
# Inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | saskylakh
# OK
# Saskylakh
# Processing Record 50 of Set 5 | halifax
# OK
# Halifax
# Processing Record 1 of Set 6 | finschhafen
# OK
# Finschhafen
# Processing Record 2 of Set 6 | ahipara
# OK
# Ahipara
# Processing Record 3 of Set 6 | aberfeldy
# OK
# Aberfeldy
# Processing Record 4 of Set 6 | karoi
# OK
# Karoi
# Processing Record 5 of Set 6 | tiksi
# OK
# Tiksi
# Processing Record 6 of Set 6 | sola
# OK
# Sola
# Processing Record 7 of Set 6 | belaya gora
# OK
# Belaya Gora
# Processing Record 8 of Set 6 | toliary
# OK
# Toliary
# City not found. Skipping...
# Processing Record 9 of Set 6 | great falls
# OK
# Great Falls
# Processing Record 10 of Set 6 | sedelnikovo
# OK
# Sedelnikovo
# City not found. Skipping...
# Processing Record 11 of Set 6 | saint anthony
# OK
# Saint Anthony
# Processing Record 12 of Set 6 | huaihua
# OK
# Huaihua
# Processing Record 13 of Set 6 | kirovskiy
# OK
# Kirovskiy
# Processing Record 14 of Set 6 | churapcha
# OK
# Churapcha
# Processing Record 15 of Set 6 | puerto leguizamo
# OK
# Puerto Leguizamo
# Processing Record 16 of Set 6 | caravelas
# OK
# Caravelas
# Processing Record 17 of Set 6 | torbay
# OK
# Torbay
# Processing Record 18 of Set 6 | general pico
# OK
# General Pico
# Processing Record 19 of Set 6 | mutengene
# OK
# Mutengene
# Processing Record 20 of Set 6 | samalaeulu
# OK
# Samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 6 | healdsburg
# OK
# Healdsburg
# Processing Record 22 of Set 6 | nemuro
# OK
# Nemuro
# Processing Record 23 of Set 6 | vicuna
# OK
# Vicuna
# Processing Record 24 of Set 6 | cherskiy
# OK
# Cherskiy
# Processing Record 25 of Set 6 | matay
# OK
# Matay
# Processing Record 26 of Set 6 | pinotepa nacional
# OK
# Pinotepa Nacional
# Processing Record 27 of Set 6 | zabol
# OK
# Zabol
# Processing Record 28 of Set 6 | luderitz
# OK
# Luderitz
# Processing Record 29 of Set 6 | kodiak
# OK
# Kodiak
# Processing Record 30 of Set 6 | matara
# OK
# Matara
# Processing Record 31 of Set 6 | yei
# OK
# Yei
# Processing Record 32 of Set 6 | dulce nombre de culmi
# OK
# Dulce Nombre De Culmi
# Processing Record 33 of Set 6 | salinas
# OK
# Salinas
# Processing Record 34 of Set 6 | tsihombe
# OK
# Tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 6 | yar-sale
# OK
# Yar-Sale
# Processing Record 36 of Set 6 | cidreira
# OK
# Cidreira
# Processing Record 37 of Set 6 | marsh harbour
# OK
# Marsh Harbour
# Processing Record 38 of Set 6 | trairi
# OK
# Trairi
# Processing Record 39 of Set 6 | severo-kurilsk
# OK
# Severo-Kurilsk
# Processing Record 40 of Set 6 | shingu
# OK
# Shingu
# Processing Record 41 of Set 6 | sao filipe
# OK
# Sao Filipe
# Processing Record 42 of Set 6 | margate
# OK
# Margate
# Processing Record 43 of Set 6 | upernavik
# OK
# Upernavik
# Processing Record 44 of Set 6 | yeppoon
# OK
# Yeppoon
# Processing Record 45 of Set 6 | daru
# OK
# Daru
# Processing Record 46 of Set 6 | harnosand
# OK
# Harnosand
# Processing Record 47 of Set 6 | lubao
# OK
# Lubao
# Processing Record 48 of Set 6 | ciras
# OK
# Ciras
# City not found. Skipping...
# Processing Record 49 of Set 6 | yumen
# OK
# Yumen
# Processing Record 50 of Set 6 | dhidhdhoo
# OK
# Dhidhdhoo
# Processing Record 1 of Set 7 | san cristobal
# OK
# San Cristobal
# Processing Record 2 of Set 7 | bandundu
# OK
# Bandundu
# Processing Record 3 of Set 7 | chenzhou
# OK
# Chenzhou
# Processing Record 4 of Set 7 | talaya
# OK
# Talaya
# Processing Record 5 of Set 7 | bedesa
# OK
# Bedesa
# Processing Record 6 of Set 7 | majene
# OK
# Majene
# Processing Record 7 of Set 7 | esmeraldas
# OK
# Esmeraldas
# Processing Record 8 of Set 7 | mayo
# OK
# Mayo
# Processing Record 9 of Set 7 | halmstad
# OK
# Halmstad
# Processing Record 10 of Set 7 | port shepstone
# OK
# Port Shepstone
# Processing Record 11 of Set 7 | salta
# OK
# Salta
# Processing Record 12 of Set 7 | grindavik
# OK
# Grindavik
# Processing Record 13 of Set 7 | saint combs
# OK
# Saint Combs
# City not found. Skipping...
# Processing Record 14 of Set 7 | peniche
# OK
# Peniche
# Processing Record 15 of Set 7 | san pedro
# OK
# San Pedro
# Processing Record 16 of Set 7 | boa vista
# OK
# Boa Vista
# Processing Record 17 of Set 7 | pisco
# OK
# Pisco
# Processing Record 18 of Set 7 | qaanaaq
# OK
# Qaanaaq
# Processing Record 19 of Set 7 | meyungs
# OK
# Meyungs
# City not found. Skipping...
# Processing Record 20 of Set 7 | pangody
# OK
# Pangody
# Processing Record 21 of Set 7 | horta
# OK
# Horta
# Processing Record 22 of Set 7 | ushtobe
# OK
# Ushtobe
# Processing Record 23 of Set 7 | chimbote
# OK
# Chimbote
# Processing Record 24 of Set 7 | victor harbor
# OK
# Victor Harbor
# Processing Record 25 of Set 7 | talnakh
# OK
# Talnakh
# Processing Record 26 of Set 7 | nakusp
# OK
# Nakusp
# Processing Record 27 of Set 7 | tema
# OK
# Tema
# Processing Record 28 of Set 7 | hanyang
# OK
# Hanyang
# Processing Record 29 of Set 7 | seara
# OK
# Seara
# Processing Record 30 of Set 7 | lakatoro
# OK
# Lakatoro
# Processing Record 31 of Set 7 | grand river south east
# OK
# Grand River South East
# City not found. Skipping...
# Processing Record 32 of Set 7 | fairbanks
# OK
# Fairbanks
# Processing Record 33 of Set 7 | kirkwood
# OK
# Kirkwood
# Processing Record 34 of Set 7 | port augusta
# OK
# Port Augusta
# Processing Record 35 of Set 7 | bandarbeyla
# OK
# Bandarbeyla
# Processing Record 36 of Set 7 | sangar
# OK
# Sangar
# Processing Record 37 of Set 7 | rondonopolis
# OK
# Rondonopolis
# Processing Record 38 of Set 7 | skagastrond
# OK
# Skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 7 | bambous virieux
# OK
# Bambous Virieux
# Processing Record 40 of Set 7 | lavrentiya
# OK
# Lavrentiya
# Processing Record 41 of Set 7 | ugep
# OK
# Ugep
# Processing Record 42 of Set 7 | hanna
# OK
# Hanna
# Processing Record 43 of Set 7 | batouri
# OK
# Batouri
# Processing Record 44 of Set 7 | steinbach
# OK
# Steinbach
# Processing Record 45 of Set 7 | petatlan
# OK
# Petatlan
# Processing Record 46 of Set 7 | isiro
# OK
# Isiro
# Processing Record 47 of Set 7 | eureka
# OK
# Eureka
# Processing Record 48 of Set 7 | beringovskiy
# OK
# Beringovskiy
# Processing Record 49 of Set 7 | illoqqortoormiut
# OK
# Illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 7 | pangnirtung
# OK
# Pangnirtung
# Processing Record 1 of Set 8 | leningradskiy
# OK
# Leningradskiy
# Processing Record 2 of Set 8 | capiibary
# OK
# Capiibary
# Processing Record 3 of Set 8 | san patricio
# OK
# San Patricio
# Processing Record 4 of Set 8 | vanimo
# OK
# Vanimo
# Processing Record 5 of Set 8 | maxixe
# OK
# Maxixe
# Processing Record 6 of Set 8 | camamu
# OK
# Camamu
# Processing Record 7 of Set 8 | terney
# OK
# Terney
# Processing Record 8 of Set 8 | olhao
# OK
# Olhao
# Processing Record 9 of Set 8 | bolshaya chernigovka
# OK
# Bolshaya Chernigovka
# City not found. Skipping...
# Processing Record 10 of Set 8 | bengkulu
# OK
# Bengkulu
# Processing Record 11 of Set 8 | mujiayingzi
# OK
# Mujiayingzi
# Processing Record 12 of Set 8 | bibbiena
# OK
# Bibbiena
# Processing Record 13 of Set 8 | carutapera
# OK
# Carutapera
# Processing Record 14 of Set 8 | pilar
# OK
# Pilar
# Processing Record 15 of Set 8 | cessnock
# OK
# Cessnock
# Processing Record 16 of Set 8 | ribeira grande
# OK
# Ribeira Grande
# Processing Record 17 of Set 8 | limbdi
# OK
# Limbdi
# Processing Record 18 of Set 8 | catuday
# OK
# Catuday
# Processing Record 19 of Set 8 | saint george
# OK
# Saint George
# Processing Record 20 of Set 8 | isla mujeres
# OK
# Isla Mujeres
# Processing Record 21 of Set 8 | biloela
# OK
# Biloela
# Processing Record 22 of Set 8 | korla
# OK
# Korla
# Processing Record 23 of Set 8 | souillac
# OK
# Souillac
# Processing Record 24 of Set 8 | inhambane
# OK
# Inhambane
# Processing Record 25 of Set 8 | khorixas
# OK
# Khorixas
# Processing Record 26 of Set 8 | ngukurr
# OK
# Ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 8 | cabatuan
# OK
# Cabatuan
# Processing Record 28 of Set 8 | guerrero negro
# OK
# Guerrero Negro
# Processing Record 29 of Set 8 | vostok
# OK
# Vostok
# Processing Record 30 of Set 8 | soyo
# OK
# Soyo
# Processing Record 31 of Set 8 | hasaki
# OK
# Hasaki
# Processing Record 32 of Set 8 | faanui
# OK
# Faanui
# Processing Record 33 of Set 8 | pontes e lacerda
# OK
# Pontes E Lacerda
# Processing Record 34 of Set 8 | fuerte olimpo
# OK
# Fuerte Olimpo
# Processing Record 35 of Set 8 | mount isa
# OK
# Mount Isa
# Processing Record 36 of Set 8 | novochernorechenskiy
# OK
# Novochernorechenskiy
# Processing Record 37 of Set 8 | umm kaddadah
# OK
# Umm Kaddadah
# Processing Record 38 of Set 8 | gulmarg
# OK
# Gulmarg
# Processing Record 39 of Set 8 | shitanjing
# OK
# Shitanjing
# Processing Record 40 of Set 8 | alofi
# OK
# Alofi
# Processing Record 41 of Set 8 | hollins
# OK
# Hollins
# Processing Record 42 of Set 8 | puerto carreno
# OK
# Puerto Carreno
# Processing Record 43 of Set 8 | cockburn harbour
# OK
# Cockburn Harbour
# City not found. Skipping...
# Processing Record 44 of Set 8 | ambilobe
# OK
# Ambilobe
# Processing Record 45 of Set 8 | codrington
# OK
# Codrington
# Processing Record 46 of Set 8 | rio gallegos
# OK
# Rio Gallegos
# Processing Record 47 of Set 8 | gimli
# OK
# Gimli
# Processing Record 48 of Set 8 | grimshaw
# OK
# Grimshaw
# Processing Record 49 of Set 8 | mehamn
# OK
# Mehamn
# Processing Record 50 of Set 8 | kulhudhuffushi
# OK
# Kulhudhuffushi
# Processing Record 1 of Set 9 | neyshabur
# OK
# Neyshabur
# Processing Record 2 of Set 9 | urengoy
# OK
# Urengoy
# Processing Record 3 of Set 9 | saint-pierre
# OK
# Saint-Pierre
# Processing Record 4 of Set 9 | nassau
# OK
# Nassau
# Processing Record 5 of Set 9 | la ronge
# OK
# La Ronge
# Processing Record 6 of Set 9 | beysehir
# OK
# Beysehir
# Processing Record 7 of Set 9 | nome
# OK
# Nome
# Processing Record 8 of Set 9 | kipushi
# OK
# Kipushi
# Processing Record 9 of Set 9 | deputatskiy
# OK
# Deputatskiy
# Processing Record 10 of Set 9 | lazaro cardenas
# OK
# Lazaro Cardenas
# Processing Record 11 of Set 9 | bolivar
# OK
# Bolivar
# Processing Record 12 of Set 9 | lamar
# OK
# Lamar
# Processing Record 13 of Set 9 | dunedin
# OK
# Dunedin
# Processing Record 14 of Set 9 | liborina
# OK
# Liborina
# Processing Record 15 of Set 9 | faya
# OK
# Faya
# Processing Record 16 of Set 9 | burica
# OK
# Burica
# City not found. Skipping...
# Processing Record 17 of Set 9 | klaksvik
# OK
# Klaksvik
# Processing Record 18 of Set 9 | inuvik
# OK
# Inuvik
# Processing Record 19 of Set 9 | amurzet
# OK
# Amurzet
# Processing Record 20 of Set 9 | emba
# OK
# Emba
# Processing Record 21 of Set 9 | tolosa
# OK
# Tolosa
# Processing Record 22 of Set 9 | karratha
# OK
# Karratha
# Processing Record 23 of Set 9 | samusu
# OK
# Samusu
# City not found. Skipping...
# Processing Record 24 of Set 9 | raudeberg
# OK
# Raudeberg
# Processing Record 25 of Set 9 | bilibino
# OK
# Bilibino
# Processing Record 26 of Set 9 | patiya
# OK
# Patiya
# Processing Record 27 of Set 9 | saint-georges
# OK
# Saint-Georges
# Processing Record 28 of Set 9 | ahuimanu
# OK
# Ahuimanu
# Processing Record 29 of Set 9 | mednogorskiy
# OK
# Mednogorskiy
# Processing Record 30 of Set 9 | mossoro
# OK
# Mossoro
# Processing Record 31 of Set 9 | marrakesh
# OK
# Marrakesh
# Processing Record 32 of Set 9 | tura
# OK
# Tura
# Processing Record 33 of Set 9 | paka
# OK
# Paka
# Processing Record 34 of Set 9 | yulara
# OK
# Yulara
# Processing Record 35 of Set 9 | portland
# OK
# Portland
# Processing Record 36 of Set 9 | lakes entrance
# OK
# Lakes Entrance
# Processing Record 37 of Set 9 | merauke
# OK
# Merauke
# Processing Record 38 of Set 9 | vila franca do campo
# OK
# Vila Franca Do Campo
# Processing Record 39 of Set 9 | makakilo city
# OK
# Makakilo City
# Processing Record 40 of Set 9 | ponta delgada
# OK
# Ponta Delgada
# Processing Record 41 of Set 9 | payson
# OK
# Payson
# Processing Record 42 of Set 9 | yarkovo
# OK
# Yarkovo
# Processing Record 43 of Set 9 | gualaquiza
# OK
# Gualaquiza
# Processing Record 44 of Set 9 | toftir
# OK
# Toftir
# City not found. Skipping...
# Processing Record 45 of Set 9 | nalut
# OK
# Nalut
# Processing Record 46 of Set 9 | filingue
# OK
# Filingue
# Processing Record 47 of Set 9 | kununurra
# OK
# Kununurra
# Processing Record 48 of Set 9 | berlevag
# OK
# Berlevag
# Processing Record 49 of Set 9 | rumonge
# OK
# Rumonge
# Processing Record 50 of Set 9 | cayenne
# OK
# Cayenne
# Processing Record 1 of Set 10 | elizabeth city
# OK
# Elizabeth City
# Processing Record 2 of Set 10 | frontera
# OK
# Frontera
# Processing Record 3 of Set 10 | bhunya
# OK
# Bhunya
# Processing Record 4 of Set 10 | blakstad
# OK
# Blakstad
# Processing Record 5 of Set 10 | ewo
# OK
# Ewo
# Processing Record 6 of Set 10 | naryan-mar
# OK
# Naryan-Mar
# Processing Record 7 of Set 10 | kotelnich
# OK
# Kotelnich
# Processing Record 8 of Set 10 | moron
# OK
# Moron
# Processing Record 9 of Set 10 | hirara
# OK
# Hirara
# Processing Record 10 of Set 10 | gyorszemere
# OK
# Gyorszemere
# Processing Record 11 of Set 10 | kavaratti
# OK
# Kavaratti
# Processing Record 12 of Set 10 | nguiu
# OK
# Nguiu
# City not found. Skipping...
# Processing Record 13 of Set 10 | guayaramerin
# OK
# Guayaramerin
# Processing Record 14 of Set 10 | alekseyevka
# OK
# Alekseyevka
# Processing Record 15 of Set 10 | wichita falls
# OK
# Wichita Falls
# Processing Record 16 of Set 10 | flinders
# OK
# Flinders
# Processing Record 17 of Set 10 | whitehorse
# OK
# Whitehorse
# Processing Record 18 of Set 10 | pokhara
# OK
# Pokhara
# Processing Record 19 of Set 10 | hazorasp
# OK
# Hazorasp
# Processing Record 20 of Set 10 | tumannyy
# OK
# Tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 10 | akyab
# OK
# Akyab
# Processing Record 22 of Set 10 | quatre cocos
# OK
# Quatre Cocos
# Processing Record 23 of Set 10 | narasannapeta
# OK
# Narasannapeta
# Processing Record 24 of Set 10 | harper
# OK
# Harper
# Processing Record 25 of Set 10 | burnie
# OK
# Burnie
# Processing Record 26 of Set 10 | miri
# OK
# Miri
# Processing Record 27 of Set 10 | mezen
# OK
# Mezen
# Processing Record 28 of Set 10 | tabarqah
# OK
# Tabarqah
# City not found. Skipping...
# Processing Record 29 of Set 10 | vila velha
# OK
# Vila Velha
# Processing Record 30 of Set 10 | gari
# OK
# Gari
# Processing Record 31 of Set 10 | pochutla
# OK
# Pochutla
# Processing Record 32 of Set 10 | pierre
# OK
# Pierre
# Processing Record 33 of Set 10 | balakhninskiy
# OK
# Balakhninskiy
# Processing Record 34 of Set 10 | atambua
# OK
# Atambua
# Processing Record 35 of Set 10 | norsup
# OK
# Norsup
# Processing Record 36 of Set 10 | alta floresta
# OK
# Alta Floresta
# Processing Record 37 of Set 10 | tefe
# OK
# Tefe
# Processing Record 38 of Set 10 | sindand
# OK
# Sindand
# City not found. Skipping...
# Processing Record 39 of Set 10 | north myrtle beach
# OK
# North Myrtle Beach
# Processing Record 40 of Set 10 | novo aripuana
# OK
# Novo Aripuana
# Processing Record 41 of Set 10 | nouadhibou
# OK
# Nouadhibou
# Processing Record 42 of Set 10 | palmer
# OK
# Palmer
# Processing Record 43 of Set 10 | bilma
# OK
# Bilma
# Processing Record 44 of Set 10 | kemi
# OK
# Kemi
# Processing Record 45 of Set 10 | sinop
# OK
# Sinop
# Processing Record 46 of Set 10 | machinga
# OK
# Machinga
# Processing Record 47 of Set 10 | camocim
# OK
# Camocim
# Processing Record 48 of Set 10 | pacific grove
# OK
# Pacific Grove
# Processing Record 49 of Set 10 | kharagpur
# OK
# Kharagpur
# Processing Record 50 of Set 10 | nizwa
# OK
# Nizwa
# Processing Record 1 of Set 11 | preobrazheniye
# OK
# Preobrazheniye
# Processing Record 2 of Set 11 | northam
# OK
# Northam
# Processing Record 3 of Set 11 | kefamenanu
# OK
# Kefamenanu
# Processing Record 4 of Set 11 | baykit
# OK
# Baykit
# Processing Record 5 of Set 11 | belmonte
# OK
# Belmonte
# Processing Record 6 of Set 11 | virginia beach
# OK
# Virginia Beach
# Processing Record 7 of Set 11 | phulji
# OK
# Phulji
# Processing Record 8 of Set 11 | poum
# OK
# Poum
# Processing Record 9 of Set 11 | skibbereen
# OK
# Skibbereen
# Processing Record 10 of Set 11 | kailua
# OK
# Kailua
# Processing Record 11 of Set 11 | la libertad
# OK
# La Libertad
# Processing Record 12 of Set 11 | bull savanna
# OK
# Bull Savanna
# Processing Record 13 of Set 11 | acari
# OK
# Acari
# Processing Record 14 of Set 11 | tommot
# OK
# Tommot
# Processing Record 15 of Set 11 | paita
# OK
# Paita
# Processing Record 16 of Set 11 | mullaitivu
# OK
# Mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 11 | waipawa
# OK
# Waipawa
# Processing Record 18 of Set 11 | qandala
# OK
# Qandala
# Processing Record 19 of Set 11 | pringsewu
# OK
# Pringsewu
# Processing Record 20 of Set 11 | maningrida
# OK
# Maningrida
# Processing Record 21 of Set 11 | riaba
# OK
# Riaba
# City not found. Skipping...
# Processing Record 22 of Set 11 | caraquet
# OK
# Caraquet
# Processing Record 23 of Set 11 | hernani
# OK
# Hernani
# Processing Record 24 of Set 11 | mporokoso
# OK
# Mporokoso
# Processing Record 25 of Set 11 | conde
# OK
# Conde
# Processing Record 26 of Set 11 | gornoye loo
# OK
# Gornoye Loo
# Processing Record 27 of Set 11 | mana
# OK
# Mana
# Processing Record 28 of Set 11 | arawa
# OK
# Arawa
# Processing Record 29 of Set 11 | atar
# OK
# Atar
# Processing Record 30 of Set 11 | palu
# OK
# Palu
# Processing Record 31 of Set 11 | hengyang
# OK
# Hengyang
# Processing Record 32 of Set 11 | hualmay
# OK
# Hualmay
# Processing Record 33 of Set 11 | nishihara
# OK
# Nishihara
# Processing Record 34 of Set 11 | sechura
# OK
# Sechura
# Processing Record 35 of Set 11 | ijaki
# OK
# Ijaki
# City not found. Skipping...
# Processing Record 36 of Set 11 | yankton
# OK
# Yankton
# Processing Record 37 of Set 11 | laramie
# OK
# Laramie
# Processing Record 38 of Set 11 | alyangula
# OK
# Alyangula
# Processing Record 39 of Set 11 | varkaus
# OK
# Varkaus
# Processing Record 40 of Set 11 | punakha
# OK
# Punakha
# Processing Record 41 of Set 11 | mouila
# OK
# Mouila
# Processing Record 42 of Set 11 | unai
# OK
# Unai
# Processing Record 43 of Set 11 | dudinka
# OK
# Dudinka
# Processing Record 44 of Set 11 | iquitos
# OK
# Iquitos
# Processing Record 45 of Set 11 | ler
# OK
# Ler
# Processing Record 46 of Set 11 | mandera
# OK
# Mandera
# Processing Record 47 of Set 11 | bakel
# OK
# Bakel
# Processing Record 48 of Set 11 | san vicente
# OK
# San Vicente
# Processing Record 49 of Set 11 | careiro da varzea
# OK
# Careiro Da Varzea
# Processing Record 50 of Set 11 | boma
# OK
# Boma
# Processing Record 1 of Set 12 | broome
# OK
# Broome
# Processing Record 2 of Set 12 | tessalit
# OK
# Tessalit
# Processing Record 3 of Set 12 | magalia
# OK
# Magalia
# Processing Record 4 of Set 12 | aloleng
# OK
# Aloleng
# Processing Record 5 of Set 12 | salekhard
# OK
# Salekhard
# Processing Record 6 of Set 12 | batagay
# OK
# Batagay
# Processing Record 7 of Set 12 | magadan
# OK
# Magadan
# Processing Record 8 of Set 12 | tuatapere
# OK
# Tuatapere
# Processing Record 9 of Set 12 | hofn
# OK
# Hofn
# Processing Record 10 of Set 12 | rorvik
# OK
# Rorvik
# Processing Record 11 of Set 12 | polczyn-zdroj
# OK
# Polczyn-Zdroj
# Processing Record 12 of Set 12 | russell
# OK
# Russell
# Processing Record 13 of Set 12 | sumbawa
# OK
# Sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 12 | beihai
# OK
# Beihai
# Processing Record 15 of Set 12 | dalvik
# OK
# Dalvik
# Processing Record 16 of Set 12 | kuche
# OK
# Kuche
# City not found. Skipping...
# Processing Record 17 of Set 12 | atasu
# OK
# Atasu
# Processing Record 18 of Set 12 | phuket
# OK
# Phuket
# Processing Record 19 of Set 12 | mandalgovi
# OK
# Mandalgovi
# Processing Record 20 of Set 12 | makat
# OK
# Makat
# Processing Record 21 of Set 12 | san juan de uraba
# OK
# San Juan De Uraba
# Processing Record 22 of Set 12 | tayshet
# OK
# Tayshet
# Processing Record 23 of Set 12 | zhuhai
# OK
# Zhuhai
# Processing Record 24 of Set 12 | nara
# OK
# Nara
# Processing Record 25 of Set 12 | bosaso
# OK
# Bosaso
# Processing Record 26 of Set 12 | doha
# OK
# Doha
# Processing Record 27 of Set 12 | bhuban
# OK
# Bhuban
# Processing Record 28 of Set 12 | hornepayne
# OK
# Hornepayne
# Processing Record 29 of Set 12 | ossora
# OK
# Ossora
# Processing Record 30 of Set 12 | french harbor
# OK
# French Harbor
# Processing Record 31 of Set 12 | karaul
# OK
# Karaul
# City not found. Skipping...
# Processing Record 32 of Set 12 | toumodi
# OK
# Toumodi
# Processing Record 33 of Set 12 | walvis bay
# OK
# Walvis Bay
# Processing Record 34 of Set 12 | carauari
# OK
# Carauari
# Processing Record 35 of Set 12 | rosa zarate
# OK
# Rosa Zarate
# Processing Record 36 of Set 12 | fuyang
# OK
# Fuyang
# Processing Record 37 of Set 12 | santiago del estero
# OK
# Santiago Del Estero
# Processing Record 38 of Set 12 | aksu
# OK
# Aksu
# Processing Record 39 of Set 12 | lata
# OK
# Lata
# Processing Record 40 of Set 12 | buqayq
# OK
# Buqayq
# City not found. Skipping...
# Processing Record 41 of Set 12 | watsa
# OK
# Watsa
# Processing Record 42 of Set 12 | chagda
# OK
# Chagda
# City not found. Skipping...
# Processing Record 43 of Set 12 | broken hill
# OK
# Broken Hill
# Processing Record 44 of Set 12 | bereda
# OK
# Bereda
# Processing Record 45 of Set 12 | puerto suarez
# OK
# Puerto Suarez
# Processing Record 46 of Set 12 | shabo
# OK
# Shabo
# Processing Record 47 of Set 12 | sitka
# OK
# Sitka
# Processing Record 48 of Set 12 | porgera
# OK
# Porgera
# Processing Record 49 of Set 12 | agirish
# OK
# Agirish
# Processing Record 50 of Set 12 | male
# OK
# Male
# Processing Record 1 of Set 13 | acoyapa
# OK
# Acoyapa
# Processing Record 2 of Set 13 | buchanan
# OK
# Buchanan
# Processing Record 3 of Set 13 | saldanha
# OK
# Saldanha
# Processing Record 4 of Set 13 | bossangoa
# OK
# Bossangoa
# Processing Record 5 of Set 13 | goure
# OK
# Goure
# Processing Record 6 of Set 13 | hearst
# OK
# Hearst
# Processing Record 7 of Set 13 | dawson creek
# OK
# Dawson Creek
# Processing Record 8 of Set 13 | sosnovo-ozerskoye
# OK
# Sosnovo-Ozerskoye
# Processing Record 9 of Set 13 | bahia blanca
# OK
# Bahia Blanca
# Processing Record 10 of Set 13 | melnikovo
# OK
# Melnikovo
# Processing Record 11 of Set 13 | shostka
# OK
# Shostka
# Processing Record 12 of Set 13 | del rio
# OK
# Del Rio
# Processing Record 13 of Set 13 | port hedland
# OK
# Port Hedland
# Processing Record 14 of Set 13 | beloha
# OK
# Beloha
# Processing Record 15 of Set 13 | prince rupert
# OK
# Prince Rupert
# Processing Record 16 of Set 13 | corinto
# OK
# Corinto
# Processing Record 17 of Set 13 | pyshchug
# OK
# Pyshchug
# Processing Record 18 of Set 13 | one hundred mile house
# OK
# One Hundred Mile House
# City not found. Skipping...
# Processing Record 19 of Set 13 | simbahan
# OK
# Simbahan
# Processing Record 20 of Set 13 | borba
# OK
# Borba
# Processing Record 21 of Set 13 | coihaique
# OK
# Coihaique
# Processing Record 22 of Set 13 | biak
# OK
# Biak
# Processing Record 23 of Set 13 | hamilton
# OK
# Hamilton
# Processing Record 24 of Set 13 | pevek
# OK
# Pevek
# Processing Record 25 of Set 13 | haines junction
# OK
# Haines Junction
# Processing Record 26 of Set 13 | kafanchan
# OK
# Kafanchan
# Processing Record 27 of Set 13 | sawakin
# OK
# Sawakin
# Processing Record 28 of Set 13 | roches noires
# OK
# Roches Noires
# City not found. Skipping...
# Processing Record 29 of Set 13 | oranjemund
# OK
# Oranjemund
# Processing Record 30 of Set 13 | kjopsvik
# OK
# Kjopsvik
# Processing Record 31 of Set 13 | debre tabor
# OK
# Debre Tabor
# Processing Record 32 of Set 13 | springbok
# OK
# Springbok
# Processing Record 33 of Set 13 | touros
# OK
# Touros
# Processing Record 34 of Set 13 | launceston
# OK
# Launceston
# Processing Record 35 of Set 13 | korcula
# OK
# Korcula
# Processing Record 36 of Set 13 | urumqi
# OK
# Urumqi
# Processing Record 37 of Set 13 | contamana
# OK
# Contamana
# Processing Record 38 of Set 13 | aquiraz
# OK
# Aquiraz
# Processing Record 39 of Set 13 | shimoda
# OK
# Shimoda
# Processing Record 40 of Set 13 | kargil
# OK
# Kargil
# Processing Record 41 of Set 13 | chelbasskaya
# OK
# Chelbasskaya
# Processing Record 42 of Set 13 | vila
# OK
# Vila
# Processing Record 43 of Set 13 | mae sai
# OK
# Mae Sai
# Processing Record 44 of Set 13 | sorland
# OK
# Sorland
# Processing Record 45 of Set 13 | bangassou
# OK
# Bangassou
# Processing Record 46 of Set 13 | xining
# OK
# Xining
# Processing Record 47 of Set 13 | uarini
# OK
# Uarini
# Processing Record 48 of Set 13 | liverpool
# OK
# Liverpool
# Processing Record 49 of Set 13 | caribou
# OK
# Caribou
# Processing Record 50 of Set 13 | villa union
# OK
# Villa Union
# Processing Record 1 of Set 14 | halalo
# OK
# Halalo
# City not found. Skipping...
# Processing Record 2 of Set 14 | rosario
# OK
# Rosario
# Processing Record 3 of Set 14 | solginskiy
# OK
# Solginskiy
# Processing Record 4 of Set 14 | progreso
# OK
# Progreso
# Processing Record 5 of Set 14 | kichmengskiy gorodok
# OK
# Kichmengskiy Gorodok
# Processing Record 6 of Set 14 | valleyview
# OK
# Valleyview
# Processing Record 7 of Set 14 | nicoya
# OK
# Nicoya
# Processing Record 8 of Set 14 | isangel
# OK
# Isangel
# Processing Record 9 of Set 14 | manavalakurichi
# OK
# Manavalakurichi
# Processing Record 10 of Set 14 | borovskoy
# OK
# Borovskoy
# Processing Record 11 of Set 14 | gat
# OK
# Gat
# Processing Record 12 of Set 14 | pasighat
# OK
# Pasighat
# Processing Record 13 of Set 14 | glazov
# OK
# Glazov
# Processing Record 14 of Set 14 | road town
# OK
# Road Town
# Processing Record 15 of Set 14 | southbridge
# OK
# Southbridge
# Processing Record 16 of Set 14 | jajce
# OK
# Jajce
# Processing Record 17 of Set 14 | nichinan
# OK
# Nichinan
# Processing Record 18 of Set 14 | north bend
# OK
# North Bend
# Processing Record 19 of Set 14 | scarborough
# OK
# Scarborough
# Processing Record 20 of Set 14 | ostrovnoy
# OK
# Ostrovnoy
# Processing Record 21 of Set 14 | felidhoo
# OK
# Felidhoo
# City not found. Skipping...
# Processing Record 22 of Set 14 | cruzeiro do sul
# OK
# Cruzeiro Do Sul
# Processing Record 23 of Set 14 | jieshi
# OK
# Jieshi
# Processing Record 24 of Set 14 | impfondo
# OK
# Impfondo
# Processing Record 25 of Set 14 | port hardy
# OK
# Port Hardy
# Processing Record 26 of Set 14 | derzhavinsk
# OK
# Derzhavinsk
# Processing Record 27 of Set 14 | roald
# OK
# Roald
# Processing Record 28 of Set 14 | labytnangi
# OK
# Labytnangi
# Processing Record 29 of Set 14 | bolshegrivskoye
# OK
# Bolshegrivskoye
# City not found. Skipping...
# Processing Record 30 of Set 14 | banganapalle
# OK
# Banganapalle
# Processing Record 31 of Set 14 | aitape
# OK
# Aitape
# Processing Record 32 of Set 14 | trzcianka
# OK
# Trzcianka
# Processing Record 33 of Set 14 | vakhtan
# OK
# Vakhtan
# Processing Record 34 of Set 14 | kachug
# OK
# Kachug
# Processing Record 35 of Set 14 | ust-bolsheretsk
# OK
# Ust-Bolsheretsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | coahuayana
# OK
# Coahuayana
# Processing Record 37 of Set 14 | ayr
# OK
# Ayr
# Processing Record 38 of Set 14 | kampene
# OK
# Kampene
# Processing Record 39 of Set 14 | ifanadiana
# OK
# Ifanadiana
# Processing Record 40 of Set 14 | brive-la-gaillarde
# OK
# Brive-La-Gaillarde
# Processing Record 41 of Set 14 | constitucion
# OK
# Constitucion
# Processing Record 42 of Set 14 | novoagansk
# OK
# Novoagansk
# Processing Record 43 of Set 14 | labuan
# OK
# Labuan
# Processing Record 44 of Set 14 | sinnamary
# OK
# Sinnamary
# Processing Record 45 of Set 14 | rostovka
# OK
# Rostovka
# Processing Record 46 of Set 14 | kihei
# OK
# Kihei
# Processing Record 47 of Set 14 | dauriya
# OK
# Dauriya
# Processing Record 48 of Set 14 | saveh
# OK
# Saveh
# Processing Record 49 of Set 14 | chicama
# OK
# Chicama
# Processing Record 50 of Set 14 | tilichiki
# OK
# Tilichiki
# Processing Record 1 of Set 15 | hualahuises
# OK
# Hualahuises
# Processing Record 2 of Set 15 | monywa
# OK
# Monywa
# Processing Record 3 of Set 15 | camopi
# OK
# Camopi
# Processing Record 4 of Set 15 | jalu
# OK
# Jalu
# Processing Record 5 of Set 15 | longlac
# OK
# Longlac
# City not found. Skipping...
# Processing Record 6 of Set 15 | bejar
# OK
# Bejar
# Processing Record 7 of Set 15 | aleksandrovskoye
# OK
# Aleksandrovskoye
# Processing Record 8 of Set 15 | karangasem
# OK
# Karangasem
# Processing Record 9 of Set 15 | vagay
# OK
# Vagay
# Processing Record 10 of Set 15 | klamath falls
# OK
# Klamath Falls
# Processing Record 11 of Set 15 | barbar
# OK
# Barbar
# City not found. Skipping...
# Processing Record 12 of Set 15 | sao sebastiao do cai
# OK
# Sao Sebastiao Do Cai
# Processing Record 13 of Set 15 | maracas
# OK
# Maracas
# Processing Record 14 of Set 15 | morondava
# OK
# Morondava
# Processing Record 15 of Set 15 | coos bay
# OK
# Coos Bay
# Processing Record 16 of Set 15 | kenai
# OK
# Kenai
# Processing Record 17 of Set 15 | vredendal
# OK
# Vredendal
# Processing Record 18 of Set 15 | lompoc
# OK
# Lompoc
# Processing Record 19 of Set 15 | itanhem
# OK
# Itanhem
# Processing Record 20 of Set 15 | bereznik
# OK
# Bereznik
# Processing Record 21 of Set 15 | chase
# OK
# Chase
# Processing Record 22 of Set 15 | waingapu
# OK
# Waingapu
# Processing Record 23 of Set 15 | uni
# OK
# Uni
# Processing Record 24 of Set 15 | narrabri
# OK
# Narrabri
# Processing Record 25 of Set 15 | ndjole
# OK
# Ndjole
# Processing Record 26 of Set 15 | sovetskiy
# OK
# Sovetskiy
# Processing Record 27 of Set 15 | carnot
# OK
# Carnot
# Processing Record 28 of Set 15 | artyk
# OK
# Artyk
# City not found. Skipping...
# Processing Record 29 of Set 15 | morelia
# OK
# Morelia
# Processing Record 30 of Set 15 | buckeye
# OK
# Buckeye
# Processing Record 31 of Set 15 | bloomingdale
# OK
# Bloomingdale
# Processing Record 32 of Set 15 | camacha
# OK
# Camacha
# Processing Record 33 of Set 15 | idenao
# OK
# Idenao
# Processing Record 34 of Set 15 | hohhot
# OK
# Hohhot
# Processing Record 35 of Set 15 | manta
# OK
# Manta
# Processing Record 36 of Set 15 | selcuk
# OK
# Selcuk
# Processing Record 37 of Set 15 | caceres
# OK
# Caceres
# Processing Record 38 of Set 15 | aartselaar
# OK
# Aartselaar
# Processing Record 39 of Set 15 | madruga
# OK
# Madruga
# Processing Record 40 of Set 15 | sorong
# OK
# Sorong
# Processing Record 41 of Set 15 | ngunguru
# OK
# Ngunguru
# Processing Record 42 of Set 15 | sidi qasim
# OK
# Sidi Qasim
# City not found. Skipping...
# Processing Record 43 of Set 15 | tezu
# OK
# Tezu
# Processing Record 44 of Set 15 | porto novo
# OK
# Porto Novo
# Processing Record 45 of Set 15 | bababe
# OK
# Bababe
# City not found. Skipping...
# Processing Record 46 of Set 15 | la asuncion
# OK
# La Asuncion
# Processing Record 47 of Set 15 | kawalu
# OK
# Kawalu
# Processing Record 48 of Set 15 | khuzdar
# OK
# Khuzdar
# Processing Record 49 of Set 15 | sergeyevka
# OK
# Sergeyevka
# Processing Record 50 of Set 15 | tiruvottiyur
# OK
# Tiruvottiyur
# City not found. Skipping...
# Processing Record 1 of Set 16 | ville-marie
# OK
# Ville-Marie
# Processing Record 2 of Set 16 | taltal
# OK
# Taltal
# Processing Record 3 of Set 16 | mazamari
# OK
# Mazamari
# Processing Record 4 of Set 16 | uglekamensk
# OK
# Uglekamensk
# Processing Record 5 of Set 16 | ipixuna
# OK
# Ipixuna
# Processing Record 6 of Set 16 | novoorsk
# OK
# Novoorsk
# Processing Record 7 of Set 16 | naze
# OK
# Naze
# Processing Record 8 of Set 16 | mareeba
# OK
# Mareeba
# Processing Record 9 of Set 16 | viedma
# OK
# Viedma
# Processing Record 10 of Set 16 | muli
# OK
# Muli
# Processing Record 11 of Set 16 | onguday
# OK
# Onguday
# Processing Record 12 of Set 16 | north platte
# OK
# North Platte
# Processing Record 13 of Set 16 | vanavara
# OK
# Vanavara
# Processing Record 14 of Set 16 | aksarka
# OK
# Aksarka
# Processing Record 15 of Set 16 | west bay
# OK
# West Bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bagdarin      RU  54.4333  113.6000     18.88        72          17
# 1       Ushuaia      AR -54.8000  -68.3000     56.82        41          20
# 2         Airai      TL  -8.9266  125.4092     62.04        91          99
# 3       Sibolga      ID   1.7427   98.7792     74.12        98         100
# 4          Hovd      MN  48.0056   91.6419     29.50        29          68
# 5     Jonesboro      US  35.8423  -90.7043     74.89        33           0
# 6        Castro      BR -24.7911  -50.0119     71.64        56          74
# 7  Norman Wells      CA  65.2820 -126.8329     35.64        93          75
# 8          Asau      RO  46.4333   26.4000     49.28        77          96
# 9   New Norfolk      AU -42.7826  147.0587     40.71        71          31
#
#    Wind Speed   Current Description
# 0        4.09            few clouds
# 1        6.91            few clouds
# 2        1.63       overcast clouds
# 3        1.32  heavy intensity rain
# 4        1.48         broken clouds
# 5        9.22             clear sky
# 6        5.93         broken clouds
# 7       10.36         broken clouds
# 8        4.45       overcast clouds
# 9        1.54      scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
print("Columns already in order")

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head()
# Out:
# Columns already in order
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bagdarin      RU  54.4333  113.6000     18.88        72          17
# 1   Ushuaia      AR -54.8000  -68.3000     56.82        41          20
# 2     Airai      TL  -8.9266  125.4092     62.04        91          99
# 3   Sibolga      ID   1.7427   98.7792     74.12        98         100
# 4      Hovd      MN  48.0056   91.6419     29.50        29          68
#
#    Wind Speed   Current Description
# 0        4.09            few clouds
# 1        6.91            few clouds
# 2        1.63       overcast clouds
# 3        1.32  heavy intensity rain
# 4        1.48         broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
